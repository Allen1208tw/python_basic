# %%
# 類別名稱
class human:
# 類別屬性 (Class Attribute)
    hands = 2
    legs = 2
#取得類別屬性的值
print(human.hands)
print(human.legs)
# Out:
# 2
# 2

# %%
# 類別名稱
class car:
# 類別屬性 (Class Attribute)
    wheel = 4

    def __init__(self):#建立物件預設第一時間要執行的函式
        print("建立一個物件")
# 方法 (Method)
print(car.wheel)#取得類別屬性的值

car1 = car() #建立物件
# Out:
# 4
# 建立一個物件
