# %% [markdown]
# |基本型態|創建方式|
# |:---:|:---:|
# | int | num = 10 |
# | float |  |
# | boolean |  |
# | string |  |

# %% [markdown]
# |容器型態|創建方式|
# |:---:|:---:|
# |list| | |
# |tuple||
# |set||
# |dict||

# %% [markdown]
# 整數 (int)、浮點數 (float)

# %%
num = 20
float_num = 12.5
print(num)
print(float_num)
# Out:
# 20
# 12.5

# %% [markdown]
# 布林值 (boolean)

# %%
parse_ok = True
prase_not_ok = False
print(parse_ok)
print(prase_not_ok)
print(type[prase_not_ok])
# Out:
# True
# False
# type[False]

# %% [markdown]
# 字串 (string)

# %%
str = "HELlO" 
print(str)
# Out:
# HELlO

# %% [markdown]
# 列表 (list)

# %%
num_list = [1, 2, 3]
print(num_list[2])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 num_list = [1, 2, 3]
# ----> 2 print(num_list[2])
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
# ---> 69 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring/_pydevd_sys_monitoring_cython.pyx:1505, in _pydevd_sys_monitoring_cython._line_event()
# -> 1505 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring/_pydevd_sys_monitoring_cython.pyx:1610, in _pydevd_sys_monitoring_cython._internal_line_event()
# -> 1610 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring/_pydevd_sys_monitoring_cython.pyx:1990, in _pydevd_sys_monitoring_cython._do_wait_suspend()
# -> 1990 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\AppData\Roaming\Python\Python312\site-packages\debugpy\_vendored\pydevd\pydevd.py:2234, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2231             from_this_thread.append(frame_custom_thread_id)
#    2233     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2234         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2236 frames_list = None
#    2238 if keep_suspended:
#    2239     # This means that we should pause again after a set next statement.
#
# File ~\AppData\Roaming\Python\Python312\site-packages\debugpy\_vendored\pydevd\pydevd.py:2303, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2300                 queue.put(internal_cmd)
#    2301                 wait_timeout = TIMEOUT_FAST
# -> 2303         notify_event.wait(wait_timeout)
#    2304         notify_event.clear()
#    2306 finally:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python312\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File c:\Users\student\AppData\Local\Programs\Python\Python312\Lib\threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
num_turple = (1, 2, 3)
print(num_turple)
# Out:
# (1, 2, 3)

# %% [markdown]
# 元組 (tuple)

# %%
num_turple = (1, 2, 3)
print(num_turple)
# Out:
# (1, 2, 3)

# %% [markdown]
# 集合 (set)

# %%
num_set = {1, 2, 3, 3}
print(num_set) #不會有重複的值
# Out:
# {1, 2, 3}

# %% [markdown]
# 字典 (dict)

# %%
user_info = {"name": "Allen", "age" : 25}
print(user_info)
print(type(user_info))
# Out:
# {'name': 'Allen', 'age': 25}
# <class 'dict'>

# %%
# 創建一個空的 dict
name = {}
print(type(name))
# Out:
# <class 'dict'>

# %%
# 創建一個空的 set
empty_set = set()
print(empty_set)
print(type(empty_set))
# Out:
# set()
# <class 'set'>
