# %%
# 自訂例外處理

# %%
# 自訂型別錯誤(TypeError)的例外處理
file = 'python.txt'

if file[-3:].lower != 'pdf':
    raise TypeError('僅能上傳pdf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # 自訂型別錯誤(TypeError)的例外處理
#       2 file = 'python.txt'
#       3
#       4 if file[-3:].lower != 'pdf':
# ----> 5     raise TypeError('僅能上傳pdf')
#
# TypeError: 僅能上傳pdf

# %% [markdown]
# ##### 設計 raise 陳述
