# %% [markdown]
# 百貨公司周年慶 消費金額超過 2000 要折 200
#
# 請撰寫一支程式
# 計算客戶消費的結帳金額

# %%
customer = 2000
if customer >= 2000:
    result = customer - 200
    print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 money = 0
# ----> 2 input(money = "請輸入金額")
#
# TypeError: Kernel.raw_input() got an unexpected keyword argument 'money'

# %%
total = int(input("請輸入金額"))
result = total // 2000
money = total - (result * 200)
print("折扣完金額是", money)
# Out:
# 折扣完金額是 4600
